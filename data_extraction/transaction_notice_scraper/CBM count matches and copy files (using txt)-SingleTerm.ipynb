# %%
import re, textract, pickle, os

# %%
# STEP 0: Alternative method is to use Ruby script PDF to text.

# STEP 1: Get file names

# in folder, click on tiny gear icon on top of the window, then select Copy "" pathname

# path = '/Users/Marcus/Documents/GitHub/LUX/10/txt/'
path = '/Users/Marcus/Google Drive/Country files - transaction raw documents/Luxembourg/CBM merger files/2019/11-2019/txt/'
# path = '/Volumes/BackupWD2/CbCM data/Luxembourg Archive/2016_unlocked/2016_3/'

# a package for navigating the operating system (just as from terminal)
# start with empty list
file_names = []
# iterate through all file names found in that path
for file in os.listdir(path):
    # append all files names to a list
    if file[0]!='.' and file[-3:]=='pdf': #to handle issue with hidden files and non-pdf files
        file_names.append(file)
file_names
# Out:
# []

# %%
# Step 2: (can be skipped if text files exists) Extract text from PDFs and save it to text
extracted_pdfs = []
                  
for file_name in file_names: 
    text = str(textract.process(path+file_name))
    # each extracted text is saved in .txt with same file name
    with open(path+file_name+'.txt','w+') as f:
        f.write(text)

# %%
# Step 3: Find patters in file, write search results to dictionary

#short list/single term:
search_terms = ['fusion transfrontalière','transfrontalière','cross-border merger','grenzüberschreitende Fusion',
                'cross-border','grenzüberschreiten','gemeinsamer Verschmelzungsplan']

#extensive list: 
# search_terms = [

# 'fusion transfrontalière', 'scission transfrontalière', 'projet de fusion', 'projet de scission', 
# 'changer la nationalité', 'changement de nationalité', 'transfert de siège transfrontalière', 
# 'transfert de siège social transfrontalière', 'transformation transfrontalière', 
# "apport partiel d'actif transfrontalier", "apport d'actif transfrontalier", "apport transfrontalier", 
# "transfert partiel d'actif transfrontalier", "transfert d'actif transfrontalier", 

    
# "parts bénéficiaires", 'part bénéficiaire', 'titres bénéficiaires', 'titre bénéficiaire', 'beneficial unit', 
# 'beneficial share', 'beneficial certificate', 
# 'founders share', 'beneficiary unit','beneficiary share',
# 'beneficiary certificate', 'beneficial certificates', 'founders share', 
# "founders’ share", "founder’s share", 'founder share', "founders’ shares", "founder’s shares",
    
# 'transfert transfrontalier', "transfert de branche d'activités transfrontalier",
# "transfert transfrontalier de branche d'activités","transfert d'universalité transfrontalier",
# "transfert transfrontalier d'universalité",
                
# "cross-border merger","cross-border seat transfer","cross-border conversion", 
# "cross-border transfer of head office", "cross-border transfer of statutory seat", 
# "cross-border transfer of registered office", "cross-border division", "cross-border demerger", 
# "cross-border de-merger", "partial transfer of assets", "transfer of assets", "cross-border transfer of assets", 
# "cross-border transfer of branch of activity", "cross-border transfer of all assets and liabilities", 
# "cross-border transfer of professional assets", "cross-border universal transfer of all assets and liabilities",
    
# "grenzüberschreitende Fusion", "grenzüberschreitende Sitzverlegung", "grenzüberschreitende Umwandlung", 
# "grenzüberschreitende Verlegung des Satzungssitzes", "grenzüberschreitende Verlegung des Gesellschaftssitzes",
# "grenzüberschreitende Spaltung", "grenzüberschreitende Vermögensübertragung", "Vermögensübertragung", 
# "grenzüberschreitende Übertragung", "grenzüberschreitende Übertragung eines Geschäftsbereichs", 
# "grenzüberschreitende Übertragung der gesamten Aktiva und Passiva", 
# "grenzüberschreitende Übertragung von Geschäftsvermögen"
               
#                ]

for file in os.listdir(path):
    # append all files names to a list
    if file[0]!='.' and file[-3:]=='txt': #to handle issue with hidden files and non-pdf files
        file_names.append(file)
file_names


empty_results = {term:None for term in search_terms}
empty_all_results = {file_name:None for file_name in file_names}


for file_name in file_names:
    with open(path+file_name,'r') as f:
        text = f.read()
    all_results = empty_all_results
    results = empty_results.copy()
    for term in search_terms:
        search = re.findall(term, text)
        results[term]=len(search)
    all_results[file_name]=results
    pickle.dump(all_results,open(path+'all_search_results.pickle','wb'))
import pprint
pprint.pprint(all_results)
# Out:
# {'B100077.pdf.txt': {'cross-border': 0,
#                      'cross-border merger': 0,
#                      'fusion transfrontalière': 0,
#                      'grenzüberschreiten': 0,
#                      'grenzüberschreitende Fusion': 0,
#                      'transfrontalière': 0},
#  'B100278.pdf.txt': {'cross-border': 0,
#                      'cross-border merger': 0,
#                      'fusion transfrontalière': 0,
#                      'grenzüberschreiten': 0,
#                      'grenzüberschreitende Fusion': 0,
#                      'transfrontalière': 0},
#  'B100324.pdf.txt': {'cross-border': 0,
#                      'cross-border merger': 0,
#                      'fusion transfrontalière': 0,
#                      'grenzüberschreiten': 0,
#                      'grenzüberschreitende Fusion': 0,
#                      'transfrontalière': 0},
#  'B100325.pdf.txt': {'cross-border': 0,
#                      'cross-border merger': 0,
# ...

# %%
# Step 4: Copy files with more than 0 keywords to a new folder
from shutil import copyfile

# read_path = '/Users/Marcus/Documents/GitHub/LUX/10/'

read_path = '/Users/Marcus/Google Drive/Country files - transaction raw documents/Luxembourg/CBM merger files/2019/11-2019/pdf/'
# change this path accordingly to read the pdf's from their location

# write_path = '/Users/Marcus/Documents/GitHub/LUX/10/results/'

write_path = '/Users/Marcus/Google Drive/Country files - transaction raw documents/Luxembourg/CBM merger files/2019/11-2019/results/'

# change path accordingly for writing and storing the sorted pdf's. 

# The subfolder 'pdf's' needs to be created manually beforehand!

all_results = pickle.load(open(path+'all_search_results.pickle','rb'))
for file in all_results:
    search_terms = list(all_results[file].keys())
    break
    
print('Created folders for the following search terms: ', search_terms)

for term in search_terms:
    new_folder_name = term
    if os.path.exists(write_path+new_folder_name)==False:
        os.makedirs(write_path+new_folder_name)
    
    for file_name in all_results:
        
        match_quantity = all_results[file_name][term]
        file_name=file_name[:-4]
        if match_quantity>0:
            copyfile(read_path+file_name,write_path+new_folder_name+'/'+file_name)
            print('File ', file_name, ' moved to folder ', term)
# Out:
# Created folders for the following search terms:  ['fusion transfrontalière', 'transfrontalière', 'cross-border merger', 'grenzüberschreitende Fusion', 'cross-border', 'grenzüberschreiten']
# File  B178462.pdf  moved to folder  fusion transfrontalière
# File  B196681.pdf  moved to folder  fusion transfrontalière
# File  B239186.pdf  moved to folder  fusion transfrontalière
# File  B224294.pdf  moved to folder  fusion transfrontalière
# File  B162056.pdf  moved to folder  fusion transfrontalière
# File  B164080.pdf  moved to folder  fusion transfrontalière
# File  B185886.pdf  moved to folder  fusion transfrontalière
# File  B96506.pdf  moved to folder  fusion transfrontalière
# File  B177985.pdf  moved to folder  fusion transfrontalière
# File  B98020.pdf  moved to folder  fusion transfrontalière
# File  B239119.pdf  moved to folder  fusion transfrontalière
# File  B74649.pdf  moved to folder  fusion transfrontalière
# File  B183593.pdf  moved to folder  fusion transfrontalière
# ...
