# %%
from bs4 import BeautifulSoup

def get_xmls_from_link(url):
    with open(url, "rb") as f:
        txt = f.read()

    bs = BeautifulSoup(txt)
    My_table = bs.find('table',{'class':'commonTable'})
    links = My_table.find_all('a')

    xmls = []

    for link in links:
        if(link.find('img')==None): continue
        if('XML' in link.find('img').get('alt')):
            xmls.append(link.get('href'))
    return xmls

# %%
import urllib.request
import ssl

context = ssl._create_unverified_context()

def get_all_transactions(publications, context, url):

    source = urllib.request.urlopen(url, context=context).read()
    soup = BeautifulSoup(source)
    
    for publication in soup.find_all('ns2:publication'):
        if 'fusion' in publication.find('ns2:prestation').text:
            publications.append([publication.find('ns2:denomination').text, publication.find('ns2:numerorcs').text, publication.find('ns2:lienpublication').text, publication.find('ns2:datedepotrcs').text])
            
    return publications

# %%
publications = []
months_data = [r'data/01-2019.html', r'data/02-2019 until 25.02.2019.html']
for url in months_data:
    xmls = get_xmls_from_link(url)
    for xml in xmls:
        publications = get_all_transactions(publications, context, xml)

# %%
publications
# Out:
# [['BANQUE DEGROOF PETERCAM LUXEMBOURG S.A.',
#   'B25459',
#   'https://gd.lu/resa/cVGrtj',
#   '31/01/2019'],
#  ['Degroof Petercam Asset Services S.A.',
#   'B104980',
#   'https://gd.lu/resa/cVGrtj',
#   '31/01/2019'],
#  ['Raphael Investments S.A.',
#   'B175744',
#   'https://gd.lu/resa/d4gPNw',
#   '31/01/2019'],
#  ['München, Alte Akademie I Beteiligung A S.à r.l.',
#   'B178432',
#   'https://gd.lu/resa/6DdWHf',
#   '29/01/2019'],
#  ['München, Alte Akademie I Beteiligung B S.à r.l.',
#   'B178434',
#   'https://gd.lu/resa/5pFDGK',
#   '29/01/2019'],
#  ['München, Alte Akademie II Beteiligung A S.à r.l',
#   'B178433',
#   'https://gd.lu/resa/6DdWHf',
#   '29/01/2019'],
#  ['München, Alte Akademie II Beteiligung B S.à r.l.',
#   'B178437',
#   'https://gd.lu/resa/5pFDGK',
#   '29/01/2019'],
#  ['München, Alte Akademie I Beteiligung A S.à r.l.',
#   'B178432',
#   'https://gd.lu/resa/5jK68T',
#   '28/01/2019'],
#  ['München, Alte Akademie I Beteiligung B S.à r.l.',
#   'B178434',
#   'https://gd.lu/resa/dnLFjx',
#   '28/01/2019'],
#  ['München, Alte Akademie III Beteiligung A S.à r.l.',
#   'B178431',
#   'https://gd.lu/resa/5jK68T',
#   '28/01/2019'],
#  ['München, Alte Akademie III Beteiligung B S.à r.l.',
#   'B178430',
#   'https://gd.lu/resa/dnLFjx',
#   '28/01/2019'],
#  ['ARHS Spikeseed S.A.', 'B198451', 'https://gd.lu/resa/cVJlLq', '25/01/2019'],
#  ['CapLinden S.A., Société de Gestion de Patrimoine Familial - SPF',
#   'B172184',
#   'https://gd.lu/resa/7fD7rk',
#   '25/01/2019'],
#  ['CapSoleil S.àr.l., société de gestion de patrimoine familial (SPF)',
#   'B172190',
#   'https://gd.lu/resa/7fD7rk',
#   '25/01/2019'],
#  ['Northern Trust Luxembourg Management Company',
#   'B99167',
#   'https://gd.lu/resa/52Tlbn',
#   '24/01/2019'],
#  ['Preval', 'B190081', 'https://gd.lu/resa/RVj3Q', '23/01/2019'],
#  ['First Names (Luxembourg) S.à r.l.',
#   'B147824',
#   'https://gd.lu/resa/9GWhZk',
#   '25/02/2019'],
#  ['SGG S.A.', 'B65906', 'https://gd.lu/resa/9GWhZk', '25/02/2019'],
#  ['Binah S.A. SPF', 'B162598', 'https://gd.lu/resa/3PqJ8d', '22/02/2019'],
#  ['Endo US Holdings Luxembourg I S.à r.l.',
#   'B197803',
#   'https://gd.lu/resa/bvbB2h',
#   '22/02/2019'],
#  ['Endo US Holdings Luxembourg II S.à r.l.',
#   'B197970',
#   'https://gd.lu/resa/bvbB2h',
#   '22/02/2019'],
#  ['Luxembourg Endo Specialty Pharmaceuticals Holding I S.à r.l.',
#   'B204925',
#   'https://gd.lu/resa/2dDX3H',
#   '22/02/2019'],
#  ['Luxembourg Endo Specialty Pharmaceuticals Holding II S.à r.l.',
#   'B204928',
#   'https://gd.lu/resa/2dDX3H',
#   '22/02/2019'],
#  ['Nothum Services S.à r.l.',
#   'B55767',
#   'https://gd.lu/resa/60kvVX',
#   '22/02/2019'],
#  ['SEPHIRA SA', 'B156655', 'https://gd.lu/resa/3PqJ8d', '22/02/2019'],
#  ['Stratex S.à r.l.', 'B171329', 'https://gd.lu/resa/60kvVX', '22/02/2019'],
#  ['UTC Fire & Security Luxembourg S.àr.l.',
#   'B151396',
#   'https://gd.lu/resa/2Sn5FC',
#   '22/02/2019'],
#  ['APS Quattro Holding S.à r.l.',
#   'B222672',
#   'https://gd.lu/resa/dnn6N2',
#   '20/02/2019'],
#  ['CORPUS SIREO  Real Estate S.à r.l.',
#   'B111358',
#   'https://gd.lu/resa/2sbk6R',
#   '20/02/2019'],
#  ['Swiss Life Fund Management (LUX) S.A.',
#   'B171124',
#   'https://gd.lu/resa/2sbk6R',
#   '20/02/2019'],
#  ['AUTOPOLIS REAL ESTATE S.A.',
#   'B43155',
#   'https://gd.lu/resa/cXrjPR',
#   '18/02/2019'],
#  ['HOWALD S.A.', 'B89386', 'https://gd.lu/resa/f3X4zZ', '18/02/2019'],
#  ['IMMOWALD S.A.', 'B88151', 'https://gd.lu/resa/f3X4zZ', '18/02/2019'],
#  ['MEIF 5 Arena GP S.à r.l.',
#   'B214039',
#   'https://gd.lu/resa/9VpWz9',
#   '18/02/2019'],
#  ['MEIF 5 Arena Holdings S.à r.l.',
#   'B217099',
#   'https://gd.lu/resa/9VpWz9',
#   '18/02/2019'],
#  ['MEIF 5 Arena S.C.A.', 'B220006', 'https://gd.lu/resa/9VpWz9', '18/02/2019'],
#  ["SOCIETE IMMOBILIERE DE L'OUEST",
#   'B74084',
#   'https://gd.lu/resa/cXrjPR',
#   '18/02/2019'],
#  ['BANQUE RAIFFEISEN', 'B20128', 'https://gd.lu/resa/31nrjB', '12/02/2019'],
#  ['BANQUE RAIFFEISEN', 'B20128', 'https://gd.lu/resa/2zSZ76', '12/02/2019'],
#  ['BANQUE RAIFFEISEN', 'B20128', 'https://gd.lu/resa/cl67Qh', '12/02/2019'],
#  ['BANQUE RAIFFEISEN', 'B20128', 'https://gd.lu/resa/9BTs7P', '12/02/2019'],
#  ['BANQUE RAIFFEISEN', 'B20128', 'https://gd.lu/resa/5LV0gp', '12/02/2019'],
#  ['BANQUE RAIFFEISEN', 'B20128', 'https://gd.lu/resa/dPRr1D', '12/02/2019'],
#  ['BANQUE RAIFFEISEN', 'B20128', 'https://gd.lu/resa/3SDKsT', '12/02/2019'],
#  ['BANQUE RAIFFEISEN', 'B20128', 'https://gd.lu/resa/7ZZGpP', '12/02/2019'],
#  ['BANQUE RAIFFEISEN', 'B20128', 'https://gd.lu/resa/99MbKg', '12/02/2019'],
#  ['BANQUE RAIFFEISEN', 'B20128', 'https://gd.lu/resa/QlbZw', '12/02/2019'],
#  ['BANQUE RAIFFEISEN', 'B20128', 'https://gd.lu/resa/4l4xtX', '12/02/2019'],
#  ['BANQUE RAIFFEISEN', 'B20128', 'https://gd.lu/resa/8g2LV0', '12/02/2019'],
#  ['BANQUE RAIFFEISEN', 'B20128', 'https://gd.lu/resa/78ZM2L', '12/02/2019'],
#  ['BANQUE RAIFFEISEN', 'B20128', 'https://gd.lu/resa/4CKKM9', '12/02/2019'],
#  ['CAISSE RAIFFEISEN BASCHARAGE-RECKANGE-SOLEUVRE',
#   'B20301',
#   'https://gd.lu/resa/9BTs7P',
#   '12/02/2019'],
#  ['CAISSE RAIFFEISEN BETTBORN-PERLE',
#   'B92046',
#   'https://gd.lu/resa/QlbZw',
#   '12/02/2019'],
#  ['CAISSE RAIFFEISEN CANTON REMICH',
#   'B20373',
#   'https://gd.lu/resa/8g2LV0',
#   '12/02/2019'],
#  ['CAISSE RAIFFEISEN DIEKIRCH FEULEN',
#   'B94447',
#   'https://gd.lu/resa/3SDKsT',
#   '12/02/2019'],
#  ['CAISSE RAIFFEISEN HOFFELT-BINSFELD-WEISWAMPACH',
#   'B94441',
#   'https://gd.lu/resa/4CKKM9',
#   '12/02/2019'],
#  ['CAISSE RAIFFEISEN JUNGLINSTER',
#   'B20380',
#   'https://gd.lu/resa/2zSZ76',
#   '12/02/2019'],
#  ['CAISSE RAIFFEISEN KAYL-ROESER',
#   'B20334',
#   'https://gd.lu/resa/5LV0gp',
#   '12/02/2019'],
#  ['CAISSE RAIFFEISEN MAMER',
#   'B20273',
#   'https://gd.lu/resa/7ZZGpP',
#   '12/02/2019'],
#  ['Caisse Raiffeisen Mersch',
#   'B20416',
#   'https://gd.lu/resa/78ZM2L',
#   '12/02/2019'],
#  ['CAISSE RAIFFEISEN MUSEL-SAUERDALL',
#   'B20415',
#   'https://gd.lu/resa/cl67Qh',
#   '12/02/2019'],
#  ['CAISSE RAIFFEISEN NIEDERANVEN/SYRDALL',
#   'B20276',
#   'https://gd.lu/resa/dPRr1D',
#   '12/02/2019'],
#  ['CAISSE RAIFFEISEN NOERDANGE-SAEUL-USELDANGE SOCIETE COOPERATIVE',
#   'B94446',
#   'https://gd.lu/resa/99MbKg',
#   '12/02/2019'],
#  ['CAISSE RAIFFEISEN WILTZ SOCIETE COOPERATIVE',
#   'B94443',
#   'https://gd.lu/resa/31nrjB',
#   '12/02/2019'],
#  ['MEIF 5 Arena GP S.à r.l.',
#   'B214039',
#   'https://gd.lu/resa/8KxZq6',
#   '15/02/2019'],
#  ['MEIF 5 Arena Holdings S.à r.l.',
#   'B217099',
#   'https://gd.lu/resa/8KxZq6',
#   '15/02/2019'],
#  ['MEIF 5 Arena S.C.A.', 'B220006', 'https://gd.lu/resa/8KxZq6', '15/02/2019'],
#  ['RAIFFEISEN MEMBERS', 'B187921', 'https://gd.lu/resa/4l4xtX', '12/02/2019'],
#  ['DA SILVA & FILS S.A.',
#   'B109099',
#   'https://gd.lu/resa/dGRmSz',
#   '13/02/2019'],
#  ['NONAC', 'B194841', 'https://gd.lu/resa/dGRmSz', '13/02/2019'],
#  ['ALOKAN S.à r.l.', 'B92593', 'https://gd.lu/resa/7bSNmF', '06/02/2019'],
#  ['ANDREWS S.à r.l.', 'B92585', 'https://gd.lu/resa/7bSNmF', '06/02/2019'],
#  ['GE Canada Holdings Luxembourg S.à r.l.',
#   'B166829',
#   'https://gd.lu/resa/hDczs',
#   '08/02/2019'],
#  ['GE HOLDINGS LUXEMBOURG & CO S.à.r.l.',
#   'B56198',
#   'https://gd.lu/resa/hDczs',
#   '08/02/2019'],
#  ['Dollar Tree International, S.à r.l.',
#   'B155745',
#   'https://gd.lu/resa/2NfF8z',
#   '07/02/2019'],
#  ['Five & Dime International, S.à r.l.',
#   'B192059',
#   'https://gd.lu/resa/2NfF8z',
#   '07/02/2019'],
#  ['Five & Dime International, S.à r.l.',
#   'B192059',
#   'https://gd.lu/resa/5cxLCB',
#   '07/02/2019'],
#  ['MARINO S.A.', 'B56112', 'https://gd.lu/resa/dV9KFL', '07/02/2019'],
#  ['Tar Heel Trading International S.à r.l.',
#   'B155008',
#   'https://gd.lu/resa/5cxLCB',
#   '07/02/2019'],
#  ['B Circle S.A.', 'B222310', 'https://gd.lu/resa/dPgmxz', '05/02/2019'],
#  ['C WORLDWIDE FUND MANAGEMENT S.A.',
#   'B53022',
#   'https://gd.lu/resa/37dKh9',
#   '04/02/2019']]
