# %%
import time
from bs4 import BeautifulSoup

def get_xmls_from_link(url):
    with open(url, "rb") as f:
        txt = f.read()

    bs = BeautifulSoup(txt)
    My_table = bs.find('table',{'class':'commonTable'})
    links = My_table.find_all('a')

    xmls = []

    for link in links:
        if(link.find('img')==None): continue
        if('XML' in link.find('img').get('alt')):
            xmls.append(link.get('href'))
    return xmls

# %% [markdown]
# ## XML-tags prior to 2019

# %%
import urllib.request
import ssl

context = ssl._create_unverified_context()

def get_all_transactions(publications, context, url):

    source = urllib.request.urlopen(url, context=context).read()
    soup = BeautifulSoup(source)
    
    for publication in soup.find_all('ns2:publication'):
        if 'Modification non statutaire des mandataires'in publication.find('ns2:prestation').text:
            
            pass
        
        elif 'K' in publication.find('ns2:numerorcs').text:
            continue
        
# there are some entries with no url to the PDF file, which is causing the error. The field shows '' in Sublime for the URL. 
# These cases concern only registration numbers starting with K... , which are skipped with 'continue'.
            
        elif 'Modification' in publication.find('ns2:prestation').text:
            publications.append([publication.find('ns2:denomination').text, publication.find('ns2:numerorcs').text, publication.find('ns2:lienpublication').text, publication.find('ns2:datedepotrcs').text])
            
        #change the search term in the elif statement accordingly.

        #Modification
        #Projet de fusion / scission / transfert de patrimoine professionnel, d’actifs, de branche d’activité
        #Immatriculation
        
        
            
    return publications

# %% [markdown]
# ## 2019 and further XML-tags

# %%
# import urllib.request
# import ssl

# context = ssl._create_unverified_context()

# def get_all_transactions(publications, context, url):

#     source = urllib.request.urlopen(url, context=context).read()
#     soup = BeautifulSoup(source)

# for publication in soup.find_all('ns2:publication'):
#         if 'Modification non statutaire des mandataires'in publication.find('ns2:prestation').text:
            
#             pass
        
#         elif 'K' in publication.find('ns2:numerorcs').text:
#             continue
        
# # there are 4 entries with no url, which is causing the error. The field shows '' in Sublime for the URL. 
# # These cases concern only K... cases, which are skipped with 'continue'.
            
#         elif 'Modification' in publication.find('ns2:prestation').text:
#             publications.append([publication.find('ns2:denomination').text, publication.find('ns2:numerorcs').text, publication.find('ns2:lienpublication').text, publication.find('ns2:datedepotrcs').text])
            
#         #change the search term in the elif statement accordingly.

#         #Modification
#         #Projet de fusion / scission / transfert de patrimoine professionnel, d’actifs, de branche d’activité
#         #Immatriculation
        
#         #to do: 01 until 11-2019 on Immatriculation
            
#     return publications
# Out:
#   File "<tokenize>", line 33
#     return publications
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
publications = []
months_data = [r'data/12-2019.html'] #adjust the file name accordingly to search the relevant month
for url in months_data:
    xmls = get_xmls_from_link(url)
    for xml in xmls:
        publications = get_all_transactions(publications, context, xml)
        #time.sleep(.300)
        
##continue with 12-2017 until 10-2017

# %%
#alternative command for complete list without truncating it. Works perfectly without the slicing.

for item in publications:
    urllib.request.urlretrieve(item[2], item[1]+".pdf")
    #time.sleep(0.33)

# %%
len(publications)
#publications
# Out:
# 49

# %%
# #f_50 = publications[0:49]
# f_100 = publications[50:100]
# f_150 = publications[100:150]
# ....
# publications[3250:3300]
# #publications[3301:3336]

# %%
big_list = []
for i in range(65):
    #print(i*50,i*50+49)
    small_list = publications[i*50:i*50+49]
    big_list.append(small_list)

# %%
big_list.append(publications[3301:3336])

# %%
len(big_list)
# Out:
# 66

# %%
for sub_list in big_list:
    for item in sub_list:
        urllib.request.urlretrieve(item[2], item[1]+".pdf")
    time.sleep(600)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-596d3751005c> in <module>
#       1 for sub_list in big_list:
#       2     for item in sub_list:
# ----> 3         urllib.request.urlretrieve(item[2], item[1]+".pdf")
#       4     time.sleep(600)
#
# /anaconda3/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     274
#     275             while True:
# --> 276                 block = fp.read(bs)
#     277                 if not block:
#     278                     break
#
# /anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     445             # Amount is given, implement using readinto
#     446             b = bytearray(amt)
# --> 447             n = self.readinto(b)
#     448             return memoryview(b)[:n].tobytes()
#     449         else:
#
# /anaconda3/lib/python3.7/http/client.py in readinto(self, b)
#     489         # connection, and the user is reading more bytes than will be provided
#     490         # (for example, reading in 1k chunks)
# --> 491         n = self.fp.readinto(b)
#     492         if not n and b:
#     493             # Ideally, we would raise IncompleteRead if the content-length
#
# /anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /anaconda3/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1050                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1051                   self.__class__)
# -> 1052             return self.read(nbytes, buffer)
#    1053         else:
#    1054             return super().recv_into(buffer, nbytes, flags)
#
# /anaconda3/lib/python3.7/ssl.py in read(self, len, buffer)
#     909         try:
#     910             if buffer is not None:
# --> 911                 return self._sslobj.read(len, buffer)
#     912             else:
#     913                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
